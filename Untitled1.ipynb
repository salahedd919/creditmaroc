# %%
import pandas as pd

# Define the file path (update with your actual file path)
file_path = 'https://prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com/e581c632-8b60-4a2d-ae6e-4d200a5fc716'

# Read the Excel file into a DataFrame
df = pd.read_excel(file_path)
data = df.iloc[:,[0,1,2,5,7,78]]
data.head()
# Out:
#        sexe  age education      marital    rev  dfo
# 0  masculin   63  doctorat         Mari  13500  non
# 1   féminin   53  doctorat  Célibataire   8500  non
# 2   féminin   53  doctorat  Célibataire   8500  non
# 3  masculin   48  doctorat         Mari   9500  oui
# 4  masculin   54  doctorat  Célibataire  10500  oui

# %%
# Out:
# 78
